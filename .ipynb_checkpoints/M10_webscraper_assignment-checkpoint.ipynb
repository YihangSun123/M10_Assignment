# %% [markdown]
# ## Module 10 Assignment - Scraping a Website
# * Author: brandon chiazza
# * version 2.0
#
# We will be creating a web scraper to parse a table from the Charities Bureau Website. From the website: “All
# charitable organizations operating in New York State are required by law to register and file annual financial reports
# with the Attorney General's Office. This includes any organization that conducts charitable activities, holds property
# that is used for charitable purposes, or solicits financial or other contributions.”

# %%
###Load modules
#!pip install webdriver-manager
import awscli
import boto3
import selenium
import pandas as pd
import time
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

####SCRAPE THE WEBSITE######
###call the webdriver
s=Service(ChromeDriverManager().install())
browser = webdriver.Chrome(service=s)

#enter the url path that needs to be accessed by webdriver
browser.get('https://www.charitiesnys.com/RegistrySearch/search_charities.jsp')

#identify xpath of location to select element
inputElement = browser.find_element(By.XPATH,"/html/body/div/div[2]/div/table/tbody/tr/td[2]/div/div/font/font/font/font/font/table/tbody/tr[4]/td/form/table/tbody/tr[2]/td[2]/input[1]")
inputElement.send_keys('0')
inputElement1 = browser.find_element(By.XPATH,"/html/body/div/div[2]/div/table/tbody/tr/td[2]/div/div/font/font/font/font/font/table/tbody/tr[4]/td/form/table/tbody/tr[10]/td/input[1]").click()
sleep(4) #allow for the page to load by adding a sleep element
#identify the table to scrape
table = browser.find_element(By.CSS_SELECTOR,'table.Bordered')
sleep(1)
#####CREATE DATE FRAME#####
#create empty dataframe
df =[]

#loop through dataframe to export table
for row in table.find_elements(By.CSS_SELECTOR,'tr'):
      cols = df.append([cell.text for cell in row.find_elements(By.CSS_SELECTOR,'td')])


#update dataframe with header 
df = pd.DataFrame(df, columns = ["Organization Name", "NY Reg #", "EIN" ,"Registrant Type","City","State"])
df1 = pd.DataFrame(df).dropna().reset_index().drop(['index'], axis=1) 
df1
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST chromedriver version for 92.0.4515 google-chrome
# Driver [C:\Users\sun\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache
#                                     Organization Name  NY Reg #        EIN  \
# 0   "Forever Captain Poodaman" The Ahmad Butler Fo...  48-07-16  843800926
# 1                                  "Studio 5404" Inc.  44-39-58  463180470
# 2                       "THEY ARE HAITIAN" FUND, INC.  20-63-46  300170128
# 3                                      "Y" Dive, Inc.  48-45-01  854252095
# 4   (ASMA) American Syrian Multicultural Associati...  42-84-63  273130182
# 5                                        #FeedHamburg  48-37-35  854150318
# 6                                   #HicksStrong Inc.  48-10-48  842612081
# 7                                #WalkAway Foundation  47-15-80  832820906
# 8                                 04/11 10:17 PM test  47-13-95  206256427
# 9                                 1/20/21 Action Fund  46-99-13  832210730
# 10                            10/40 Connections, Inc.  45-70-15  621825230
# 11                             1000 Feet Project, Inc  45-00-14  473820859
# 12                          1000 Islands Hose Haulers  45-38-38  454570241
# 13                              1004 Foundation, Inc.  45-00-13  463110658
# 14  100 BLACK MEN OF LONG ISLAND DEVELOPMENT GROUP...  20-08-47  113617702
#
#    Registrant Type              City State
# 0              NFP      PHILADELPHIA    PA
# 1              NFP        MASSAPAQUA    NY
# 2              NFP            HUDSON    NY
# 3              NFP      SAINT ALBANS    NY
# 4              NFP          BROOKLYN    NY
# 5              NFP           HAMBURG    NY
# 6              NFP      CLIFTON PARK    NY
# 7              NFP          CARLSBAD    CA
# 8              NFP            ALBANY    NY
# 9              NFP     SAN FRANCISCO    CA
# 10             NFP            HIXSON    TN
# 11             NFP          NEW YORK    NY
# 12             NFP          CARTHAGE    NY
# 13             NFP  LONG ISLAND CITY    NY
# 14             NFP         HEMPSTEAD    NY

# %%
from boto3.session import Session
session = Session(aws_access_key_id='AKIAWXKUJHT6LQPJRJ6N', aws_secret_access_key='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', region_name='us-east-1')
#获取s3连接的session
s3 = session.resource('s3')
#列处所有的bucket 
for bucket in s3.buckets.all():
    print('bucket name:%s'%bucket.name)
# Out:
# bucket name:123321ddd
# bucket name:assignment4-ys
# bucket name:information-arch-yihangsun-assignment-8a

# %%
response=s3.create_bucket(
    ACL='private',
    Bucket='m10-assignment'
)

# %%
response
# Out:
# s3.Bucket(name='m10-assignment')

# %%
df.csv=df.to_csv(index=False, line_terminator='\n')

# %%
client = session.client("s3")

# %%
bucket = 'm10-assignment' 
upload_data = df.csv
upload_key = "M10-YihangSun.csv"
file_obj = s3.Bucket(bucket).put_object(Key=upload_key, Body=upload_data)
print(file_obj)
# Out:
# s3.Object(bucket_name='m10-assignment', key='M10-YihangSun.csv')

# %% [markdown]
# # Part2

# %%
###Load modules
#!pip install webdriver-manager
import awscli
import boto3
import selenium
import pandas as pd
import time
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

####SCRAPE THE WEBSITE######
###call the webdriver
s=Service(ChromeDriverManager().install())
browser = webdriver.Chrome(service=s)

#enter the url path that needs to be accessed by webdriver
browser.get('https://www.charitiesnys.com/RegistrySearch/search_charities.jsp')

#identify xpath of location to select element
inputElement = browser.find_element(By.XPATH,"/html/body/div/div[2]/div/table/tbody/tr/td[2]/div/div/font/font/font/font/font/table/tbody/tr[4]/td/form/table/tbody/tr[2]/td[2]/input[1]")
inputElement.send_keys('0')
inputElement1 = browser.find_element(By.XPATH,"/html/body/div/div[2]/div/table/tbody/tr/td[2]/div/div/font/font/font/font/font/table/tbody/tr[4]/td/form/table/tbody/tr[10]/td/input[1]").click()
sleep(4) #allow for the page to load by adding a sleep element
#identify the table to scrape
table = browser.find_element(By.CSS_SELECTOR,'table.Bordered')
sleep(1)
#####CREATE DATE FRAME#####
#create empty dataframe
df2 =[]

# Number of pages
num_pages = [1,2,3,4,5,6,7]

# For Loop through all pages
for x in num_pages:
    table = browser.find_element_by_css_selector('table.Bordered')
    
# #loop through dataframe to export table
    
    for row in table.find_elements_by_css_selector('tr'):
        cols = df2.append([cell.text for cell in row.find_elements_by_css_selector('td')])
    
# Pagination
    p = browser.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr/td[3]/div/div/span[2]/a['+str(x)+']').click()

#update dataframe with header 
df2 = pd.DataFrame(df2, columns = ["Organization Name", "NY Reg #", "EIN" ,"Registrant Type","City","State"])


df3 = pd.DataFrame(df2).dropna().reset_index().drop(['index'], axis=1) 


pd.set_option('display.max_rows', None)

df3
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST chromedriver version for 92.0.4515 google-chrome
# Driver [C:\Users\sun\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache
# <ipython-input-33-94fd35374f61>:39: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   table = browser.find_element_by_css_selector('table.Bordered')
# C:\Users\sun\av3\lib\site-packages\selenium\webdriver\remote\webelement.py:502: UserWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   warnings.warn("find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead")
# <ipython-input-33-94fd35374f61>:47: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   p = browser.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr/td[3]/div/div/span[2]/a['+str(x)+']').click()
#                                      Organization Name  NY Reg #        EIN  \
# 0    "Forever Captain Poodaman" The Ahmad Butler Fo...  48-07-16  843800926
# 1                                   "Studio 5404" Inc.  44-39-58  463180470
# 2                        "THEY ARE HAITIAN" FUND, INC.  20-63-46  300170128
# 3                                       "Y" Dive, Inc.  48-45-01  854252095
# 4    (ASMA) American Syrian Multicultural Associati...  42-84-63  273130182
# 5                                         #FeedHamburg  48-37-35  854150318
# 6                                    #HicksStrong Inc.  48-10-48  842612081
# 7                                 #WalkAway Foundation  47-15-80  832820906
# 8                                  04/11 10:17 PM test  47-13-95  206256427
# 9                                  1/20/21 Action Fund  46-99-13  832210730
# 10                             10/40 Connections, Inc.  45-70-15  621825230
# 11                              1000 Feet Project, Inc  45-00-14  473820859
# 12                           1000 Islands Hose Haulers  45-38-38  454570241
# 13                               1004 Foundation, Inc.  45-00-13  463110658
# 14   100 BLACK MEN OF LONG ISLAND DEVELOPMENT GROUP...  20-08-47  113617702
# 15                             100 BLACKS WHO CARE INC  06-42-84  311628801
# 16       100 BLACK WOMEN OF LONG ISLAND FOUNDATION INC  05-79-45  113101805
#
# 25              NFP            MT. KISCO    NY
# 26              NFP             NEW YORK    NY
# 27              NFP              JAMAICA    NY
# 28              NFP   COLD SPRING HARBOR    NY
# 29              NFP                BRONX    NY
# 30              NFP         PHILADELPHIA    PA
# 31              NFP           MASSAPAQUA    NY
# 32              NFP               HUDSON    NY
# 33              NFP         SAINT ALBANS    NY
# 34              NFP             BROOKLYN    NY
# 35              NFP              HAMBURG    NY
# 36              NFP         CLIFTON PARK    NY
# 37              NFP             CARLSBAD    CA
# 38              NFP               ALBANY    NY
# 39              NFP        SAN FRANCISCO    CA
# 40              NFP               HIXSON    TN
# 41              NFP             NEW YORK    NY
# 42              NFP             CARTHAGE    NY
# 43              NFP     LONG ISLAND CITY    NY
# 44              NFP            HEMPSTEAD    NY
# 45              NFP             NEW YORK    NY
# 46              NFP              BUFFALO    NY
# 47              NFP             NEW YORK    NY
# 48              NFP             BROOKLYN    NY
# 49              NFP             BROOKLYN    NY
# 50              NFP           LACKAWANNA    NY
# 51              NFP             NEW YORK    NY
# 52              NFP             FLORENCE    NJ
# 53              NFP             BROOKLYN    NY
# 54              NFP              FAIRFAX    VA
# 55              NFP            LEVITTOWN    NY
# 56              NFP              BUFFALO    NY
# 57              NFP             BROOKLYN    NY
# 58              NFP             NEW YORK    NY
# 59              NFP             BROOKLYN    NY
# 60              NFP             BROOKLYN    NY
# 61              NFP          GARDEN CITY    NY
# 62              NFP             NEW YORK    NY
# 63              NFP              BUFFALO    NY
# 64              NFP                BRONX    NY
# 65              NFP            ROCHESTER    NY
# 66              NFP              ATLANTA    GA
# 67              NFP     LONG ISLAND CITY    NY
# 68              NFP             NEW YORK    NY
# 69              NFP  SPRINGFIELD GARDENS    NY
# 70              NFP            MT. KISCO    NY
# 71              NFP             NEW YORK    NY
# 72              NFP              JAMAICA    NY
# 73              NFP   COLD SPRING HARBOR    NY
# 74              NFP                BRONX    NY
# 75              NFP             NEW YORK    NY
# 76              NFP              BUFFALO    NY
# 77              NFP             NEW YORK    NY
# 78              NFP             BROOKLYN    NY
# 79              NFP             BROOKLYN    NY
# 80              NFP           LACKAWANNA    NY
# 81              NFP             NEW YORK    NY
# 82              NFP             FLORENCE    NJ
# 83              NFP             BROOKLYN    NY
# 84              NFP              FAIRFAX    VA
# 85              NFP            LEVITTOWN    NY
# 86              NFP              BUFFALO    NY
# 87              NFP             BROOKLYN    NY
# 88              NFP             NEW YORK    NY
# 89              NFP             BROOKLYN    NY
# 90              NFP           GREENVILLE    SC
# 91              NFP             BROOKLYN    NY
# 92              NFP                GERRY    NY
# 93              NFP             NEW YORK    NY
# 94              NFP          FULTONVILLE    NY
# 95              NFP             BROOKLYN    NY
# 96              NFP              JAMAICA    NY
# 97              NFP             NEW YORK    NY
# 98              NFP                HOMER    NY
# 99              NFP                PROVO    UT
# 100             NFP                BRONX    NY
# 101             NFP              CHICAGO    IL
# 102             NFP                BRONX    NY
# 103             NFP             BROOKLYN    NY
# 104             NFP             WOODMERE    NY

# %%
df3.csv=df.to_csv(index=False, line_terminator='\n')

# %%
bucket = 'm10-assignment' 
upload_data = df3.csv
upload_key = "Update-M10-YihangSun.csv"
file_obj = s3.Bucket(bucket).put_object(Key=upload_key, Body=upload_data)
print(file_obj)
# Out:
# s3.Object(bucket_name='m10-assignment', key='Update-M10-YihangSun.csv')
